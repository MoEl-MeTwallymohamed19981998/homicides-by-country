# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Importing Data

# %%
df = pd.read_csv(r'C:\Users\el mostafa\Downloads\homicide_by_countries.csv')

# %%
df.head(10)
# Out:
#               Location    Region        Subregion  Rate   Count  Year
# 0          Afghanistan      Asia    Southern Asia   6.7  2474.0  2018
# 1              Albania    Europe  Southern Europe   2.1    61.0  2020
# 2              Algeria    Africa  Northern Africa   1.3   580.0  2020
# 3              Andorra    Europe  Southern Europe   2.6     2.0  2020
# 4               Angola    Africa    Middle Africa   4.8  1217.0  2012
# 5             Anguilla  Americas        Caribbean  28.3     4.0  2014
# 6  Antigua and Barbuda  Americas        Caribbean   9.2     9.0  2020
# 7            Argentina  Americas    South America   5.3  2416.0  2020
# 8              Armenia      Asia     Western Asia   1.8    52.0  2020
# 9                Aruba  Americas        Caribbean   1.9     2.0  2014

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Location   197 non-null    object
#  1   Region     197 non-null    object
#  2   Subregion  196 non-null    object
#  3   Rate       197 non-null    float64
#  4   Count      196 non-null    float64
#  5   Year       197 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 9.5+ KB

# %%
df.isnull().sum()
# Out:
# Location     3
# Region       3
# Subregion    4
# Rate         3
# Count        4
# Year         3
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Location   195 non-null    object
#  1   Region     195 non-null    object
#  2   Subregion  195 non-null    object
#  3   Rate       195 non-null    float64
#  4   Count      195 non-null    float64
#  5   Year       195 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 10.7+ KB

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              Rate         Count
# count  193.000000    193.000000
# mean     6.906218   1960.549223
# std      9.630927   6585.021174
# min      0.000000      0.000000
# 25%      1.100000     26.000000
# 50%      2.600000    128.000000
# 75%      7.900000    788.000000
# max     49.300000  47722.000000

# %%
i=df[df['Year']=='12/11/2015'].index
i
# Out:
# Index([180], dtype='int64')

# %%
df.drop(i,inplace=True)

# %%
i=df[df['Year']=='12/14/2013'].index
i
# Out:
# Index([168], dtype='int64')

# %%
df.drop(i,inplace=True)

# %%
df['Location'].value_counts()
# Out:
# Location
# Afghanistan    1
# Paraguay       1
# New Zealand    1
# Nicaragua      1
# Niger          1
#               ..
# Greenland      1
# Grenada        1
# Guadeloupe     1
# Guatemala      1
# Zimbabwe       1
# Name: count, Length: 191, dtype: int64

# %%
df1= df[['Location','Count']].sort_values(by='Count',ascending=False)
df1
# Out:
#             Location    Count
# 26            Brazil  47722.0
# 125          Nigeria  44200.0
# 78             India  40651.0
# 111           Mexico  36579.0
# 188    United States  21570.0
# ..               ...      ...
# 73          Holy See      0.0
# 21           Bermuda      0.0
# 84       Isle of Man      0.0
# 38   Channel Islands      0.0
# 112           Monaco      0.0
#
# [191 rows x 2 columns]

# %%
df1.head(10)
# Out:
#           Location    Count
# 26          Brazil  47722.0
# 125        Nigeria  44200.0
# 78           India  40651.0
# 111         Mexico  36579.0
# 188  United States  21570.0
# 162   South Africa  19846.0
# 118        Myanmar  15299.0
# 41        Colombia  11520.0
# 143         Russia  10697.0
# 192      Venezuela  10598.0

# %%
df1.head(10).plot(kind='bar',x='Location',y='Count',color='red')
# Out:
# <Axes: xlabel='Location'>

# 106  2019    3.0
# 66   2016    3.0
# 5    2014    4.0
# 77   2020    5.0
# 36   2014    5.0
# 152  2011    6.0
# 107  2020    7.0
# 6    2020    9.0
# 159  2020   10.0
# 146  2020   10.0
# 148  2016   10.0
# 157  2019   10.0
# 108  2009   11.0
# 161  2020   11.0
# 110  2009   12.0
# 137  2020   12.0
# 128  2020   14.0
# 67   2020   14.0
# 46   2020   15.0
# 49   2020   15.0
# 141  2009   15.0
# 114  2020   18.0
# 22   2020   19.0
# 150  2019   19.0
# 70   2017   21.0
# 75   2020   22.0
# 68   2016   23.0
# 126  2018   23.0
# 140  2019   24.0
# 45   2007   26.0
# 60   2009   30.0
# 127  2020   31.0

# %%
df2=df2.groupby('Year').sum()
df2.sort_values(by='Count',ascending=False)
# Out:
#          Count
# Year
# 2020  231992.0
# 2019   54859.0
# 2018   31599.0
# 2012   15378.0
# 2021   15299.0
# 2017    6924.0
# 2016    6222.0
# 2013    5782.0
# 2014    3040.0
# 2011    2481.0
# 2015    2447.0
# 2008    1702.0
# 2010     304.0
# 2006     205.0
# 2009      69.0
# 2007      26.0

# %%
df2.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
df3=df[['Region','Count']]
df3
# Out:
#        Region    Count
# 0        Asia   2474.0
# 1      Europe     61.0
# 2      Africa    580.0
# 3      Europe      2.0
# 4      Africa   1217.0
# ..        ...      ...
# 192  Americas  10598.0
# 194      Asia   1358.0
# 196      Asia   1703.0
# 197    Africa    853.0
# 199    Africa    981.0
#
# [191 rows x 2 columns]

# %%
df3=df3.groupby('Region').sum()
df3
# Out:
#              Count
# Region
# Africa     99481.0
# Americas  153540.0
# Asia      105092.0
# Europe     19869.0
# Oceania      347.0

# %%
df3.sort_values(by='Count',ascending=False).plot(kind='barh')
# Out:
# <Axes: ylabel='Region'>

# %%
df4=df[['Subregion','Count']]
df4
# Out:
#               Subregion    Count
# 0         Southern Asia   2474.0
# 1       Southern Europe     61.0
# 2       Northern Africa    580.0
# 3       Southern Europe      2.0
# 4         Middle Africa   1217.0
# ..                  ...      ...
# 192       South America  10598.0
# 194  South-Eastern Asia   1358.0
# 196        Western Asia   1703.0
# 197      Eastern Africa    853.0
# 199      Eastern Africa    981.0
#
# [191 rows x 2 columns]

# %%
df4=df4.groupby('Subregion').sum()
df4.sort_values(by='Count',ascending=False).plot(kind='bar',color='green')
# Out:
# <Axes: xlabel='Subregion'>

# %%
df5=df[['Location','Rate']]
df5.value_counts()
# Out:
# Location     Rate
# Afghanistan  6.7     1
# Oman         0.3     1
# Nepal        2.3     1
# Netherlands  0.6     1
# New Zealand  2.6     1
#                     ..
# Greece       0.8     1
# Greenland    5.3     1
# Grenada      12.4    1
# Guadeloupe   5.8     1
# Zimbabwe     7.5     1
# Name: count, Length: 191, dtype: int64

# %%
df5.sort_values(by='Rate',ascending=False).head(5).plot(kind='bar',x='Location',y='Rate')
# Out:
# <Axes: xlabel='Location'>

# %%
df['Subregion'].value_counts()
# Out:
# Subregion
# Caribbean                 24
# Western Asia              19
# Southern Europe           17
# Northern Europe           15
# Eastern Africa            15
# South America             12
# Western Africa            11
# Eastern Europe            10
# South-Eastern Asia        10
# Southern Asia              9
# Western Europe             9
# Central America            8
# Eastern Asia               7
# Northern America           5
# Southern Africa            5
# Northern Africa            5
# Middle Africa              4
# Central Asia               4
# Australia, New Zealand     2
# Name: count, dtype: int64

# %%
df6 = df[['Subregion','Rate']]
df6
# Out:
#               Subregion  Rate
# 0         Southern Asia   6.7
# 1       Southern Europe   2.1
# 2       Northern Africa   1.3
# 3       Southern Europe   2.6
# 4         Middle Africa   4.8
# ..                  ...   ...
# 192       South America  36.7
# 194  South-Eastern Asia   1.5
# 196        Western Asia   6.8
# 197      Eastern Africa   5.4
# 199      Eastern Africa   7.5
#
# [191 rows x 2 columns]

# %%
df6=df6.groupby(df6['Subregion']).mean()
df6
# Out:
#                              Rate
# Subregion
# Australia, New Zealand   1.750000
# Caribbean               18.066667
# Central America         21.912500
# Central Asia             2.500000
# Eastern Africa           6.100000
# Eastern Asia             1.257143
# Eastern Europe           2.410000
# Middle Africa            7.400000
# Northern Africa          3.020000
# Northern America         5.920000
# Northern Europe          1.380000
# South America           13.666667
# South-Eastern Asia       4.600000
# Southern Africa         23.160000
# Southern Asia            3.000000
# Southern Europe          1.317647
# Western Africa           3.981818
# Western Asia             2.557895
# Western Europe           0.933333

# %%
df6.sort_values(by='Rate',ascending=False).head(10).plot(kind='barh',color='yellow')
# Out:
# <Axes: ylabel='Subregion'>

# %%
df['Region'].value_counts()
# Out:
# Region
# Europe      51
# Asia        49
# Americas    49
# Africa      40
# Oceania      2
# Name: count, dtype: int64

# %%
df7=df[['Region','Rate']]
df7
# Out:
#        Region  Rate
# 0        Asia   6.7
# 1      Europe   2.1
# 2      Africa   1.3
# 3      Europe   2.6
# 4      Africa   4.8
# ..        ...   ...
# 192  Americas  36.7
# 194      Asia   1.5
# 196      Asia   6.8
# 197    Africa   5.4
# 199    Africa   7.5
#
# [191 rows x 2 columns]

# %%
df7=df7.groupby('Region').mean()
df7
# Out:
#                Rate
# Region
# Africa     7.395000
# Americas  16.377551
# Asia       2.865306
# Europe     1.482353
# Oceania    1.750000

# %%
df7.sort_values(by='Rate',ascending=False).plot(kind='bar',color='green')
# Out:
# <Axes: xlabel='Region'>

# %%
df8=df[['Year','Rate']]
df8
# Out:
#      Year  Rate
# 0    2018   6.7
# 1    2020   2.1
# 2    2020   1.3
# 3    2020   2.6
# 4    2012   4.8
# ..    ...   ...
# 192  2018  36.7
# 194  2011   1.5
# 196  2013   6.8
# 197  2015   5.4
# 199  2012   7.5
#
# [191 rows x 2 columns]

# %%
df8=df8.groupby('Year').mean()
df8.sort_values(by='Rate',ascending=False).plot()
# Out:
# <Axes: xlabel='Year'>
